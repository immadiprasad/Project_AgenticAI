# %%
product_name = "Shoes"
print(product_name)
# Out:
# Shoes

# %%
# Store the product details
product_name = "T-shirt"
price = 499.99
available = True

# Show all product details
print("Product name:", product_name)
print("Price:", price)
print("Available:", available)
# Out:
# Product name: T-shirt
# Price: 499.99
# Available: True

# %%
# Ask the user for product details
product_name = input("Enter the product name: ")
price = float(input("Enter product price: "))
quantity = int(input("Enter quantity: "))

# Show the details back to the user
print("Product:", product_name)
print("Price:", price)
print("Quantity:", quantity)
# Out:
# Enter the product name: Tablet
# Enter product price: 2000
# Enter quantity: 5
# Product: Tablet
# Price: 2000.0
# Quantity: 5

# %%
print(f"You selected {product_name}, and it costs ${price}. Thank you!")
# Out:
# You selected Tablet, and it costs $2000.0. Thank you!

# %%
# Ask the user for two prices and calculate their sum
price1 = float(input("Enter first price: "))
price2 = float(input("Enter second price: "))

total = price1 + price2
print("Sum:", total)
# Out:
# Enter first price: 1500
# Enter second price: 500
# Sum: 2000.0

# %%
# Ask the user for two prices and calculate their difference
price1 = float(input("Enter first price: "))
price2 = float(input("Enter second price: "))

difference = price1 - price2
print("Difference:", difference)
# Out:
# Enter first price: 1500
# Enter second price: 500
# Difference: 1000.0

# %%
# Ask the user for a price and check if it is exactly 500
price = float(input("Enter the price: "))

is_equal = price == 500
print("Is the price exactly 500?", is_equal)
# Out:
# Is the price exactly 500? False

# %%
# Ask the user for a price and availability, then check both conditions
price = float(input("Enter a price: "))
available = input("Is the product available? (True/False): ") == "True"

result = price < 1000 or available
print(result)
# Out:
# False

# %%
# Ask the user for a price and apply a discount based on price range
price = float(input("Enter price: "))

if price > 2000:
    discounted_price = price * 0.8
    print("Discounted price:", discounted_price)
elif price > 1000:
    discounted_price = price * 0.9
    print("Discounted price:", discounted_price)
else:
    print("No discount")
# Out:
# 10% discount applied. New price: 1125.0

# %%
# Ask the user for a price and keep prompting until the input is valid
while True:
    user_input = input("Enter the price: ")

    try:
        price = float(user_input)
        if price < 0:
            print("Price cannot be negative. Try again.")
            continue
        break
    except ValueError:
        print("Invalid input. Please enter a number.")

if price > 2000:
    discount_price = price * 0.8
    print(f"Discounted price: ${discount_price:.2f}")
elif price > 1000:
    discount_price = price * 0.9
    print(f"Discounted price: ${discount_price:.2f}")
else:
    print("No discount")
# Out:
# Invalid input. Please enter a number.
# Discounted price: $8000.00
