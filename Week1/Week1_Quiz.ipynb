# %%
def func(x, lst=[]):
    lst.append(x)
    return lst

print(func(1))
print(func(2))
# Out:
# [1]
# [1, 2]

# %%
l = [1, 2, 3]
a = l
l.append([4, 5])
a[0] = 10
print(l, a)
# Out:
# [10, 2, 3, [4, 5]] [10, 2, 3, [4, 5]]

# %%
d = {'x': 1, 'y': 2}
print(d.get('z', 0))
# Out:
# 0

# %%
result = ""
for ch in "python":
    if ch in "aeiou":
        continue
    result += ch
print(result)
# Out:
# pythn

# %%
result = ""
for ch in "python":
    if ch in "aeiou":
        result += ch
print(result)

# %%
def func(a, b=5, c=10):
    return a + b + c

print(func(1,b=2,c=20))
# Out:
# 23
