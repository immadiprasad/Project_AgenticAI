# %%
# Store product names in a single variable using a list
product_names = ["T-Shirt", "Shoes", "Hats"]
updated_product_names = product_names + ["Pants"]
last_two_products = updated_product_names[-2:]

print(product_names)
print(updated_product_names)
print(updated_product_names[3])
print(last_two_products)
# Out:
# ['T-Shirt', 'Shoes', 'Hat']
# ['T-Shirt', 'Shoes', 'Hat', 'Pants']
# Pants
# ['Hat', 'Pants']

# %%
new_list = [10, 20, 30, 40]
last_two_elements = new_list[-2:]

print(new_list)
print(last_two_elements)

# %%
# Store product categories in a tuple so they are not changed
product_categories = ("Electronics", "Clothing")

print(product_categories)

# %%
# Store product names and prices in a dictionary
product_prices = {
    "T-Shirt": 499.99,
    "Shoes": 899.99,
    "Hat": 199.99,
    "Pants": 599.99
}

product_name = input("Enter the product name: ")
price = product_prices.get(product_name)

if price is not None:
    print(f"The price of {product_name} is ${price:.2f}")
else:
    print("Product not found")

# %%
print(price)

# %%
# Add a new product to the dictionary
product_prices["iPod"] = 200

print(product_prices)

# %%
# Ask for a product name and show its price
product_prices = {
    "T-Shirt": 499.99,
    "Shoes": 899.99,
    "Hat": 199.99,
    "Pants": 599.99,
    "iPod": 200
}

product_name = input("Enter the product name: ")

if product_name in product_prices:
    print(f"The price of {product_name} is ${product_prices[product_name]:.2f}")
else:
    print("Product not found")

# %%
# Go through a list of products and print each name
products = ["T-Shirt", "Shoes", "Hat", "Pants", "iPod"]

for product in products:
    print(product)

# %%
# Go through a list of products and print each name with a counter
products = []

for counter, product in enumerate(products, start=1):
    print(counter, product)

# %%
# Start with an empty list and keep adding product names until the user enters "exit"
products = []

while True:
    product_name = input("Enter a product name (or type exit to stop): ")

    if product_name == "exit":
        break

    products.append(product_name)

print(products)

# %%
# Start with an empty list and keep adding positive prices until the user enters 0
prices = []

while True:
    price = float(input("Enter a price (0 to stop): "))

    if price == 0:
        break

    if price < 0:
        print("Negative prices are not added.")
        continue

    prices.append(price)

print(prices)

# %%
# Start with an empty list and keep adding positive prices until the user enters 0
prices = []

while True:
    user_input = input("Enter a price (0 to stop): ")

    try:
        price = float(user_input)
    except ValueError:
        print("Invalid input. Please enter a number.")
        continue

    if price == 0:
        break

    if price < 0:
        print("Negative prices are not added.")
        continue

    # Completed Logic
    prices.append(price)

print(prices)

# %%
# customer 1
price1 = 499.99
price2 = 899.99
total_price = price1 + price2

if total_price > 1000:
    discount = total_price * 0.1
else:
    discount = 0

final = total_price - discount
print(final)

# customer 2
price1 = 499.99
price2 = 199.99
total_price = price1 + price2

if total_price > 1000:
    discount = total_price * 0.1
else:
    # Completed Logic
    discount = 0

final = total_price - discount
print(final)

# %%
def calculate_final_price(price1, price2):
    total_price = price1 + price2

    if total_price > 1000:
        discount = total_price * 0.1
    else:
        discount = 0

    final_price = total_price - discount
    return final_price

# customer 1
final_1 = calculate_final_price(499.99, 899.99)
print(final_1)

# customer 2
# Completed based on the pattern above
final_2 = calculate_final_price(499.99, 199.99)
print(final_2)

# %%
def calculate_bill(amount1, amount2):
    total = amount1 + amount2
    return total

print(calculate_bill(1000, 500))
